# %% [markdown]
# # Acerca del conjunto de datos
#
# ## Tabla: aircrafts_data

# %%
import pandas as pd
data = {
    'Nombre de la columna': ['aircraft_code', 'modelo', 'gama'],
    'Tipo de dato': ['carácter(3)', 'jsonb', 'entero'],
    'Descripcion': ['Código de la aeronave', 'Maqueta de avión en formato JSON', 'El alcance de la aeronave']
}
df = pd.DataFrame(data)
df
# Out:
#   Nombre de la columna Tipo de dato                       Descripcion
# 0        aircraft_code  carácter(3)             Código de la aeronave
# 1               modelo        jsonb  Maqueta de avión en formato JSON
# 2                 gama       entero         El alcance de la aeronave

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
