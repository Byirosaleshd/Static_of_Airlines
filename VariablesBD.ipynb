# %% [markdown]
# aircrafts_data
# -aircraft_code
# -model
# -range
#
# airports_data
# -airport_code
# -airpot_name
# -city
# -coordinates
# -timezone
#
# boarding_passes
# -ticket_no
# -flight_id
# -boarding_no
# -seat_no
#
# bookings
# -book_ref
# -book_date
# -total_amount
#
# flights
# -flight_id
# -flight_no
# -scheduled_departure
# -scheduled_arrival
# -departure_airport
# -arrival_airport
# -status
# -aircraft_code
# -actual_departure
# -actual_arrival
#
# seats
# -aircraft_code
# -seat_no
# -fare_conditions
#
# ticket_flights
# -ticket_no
# -flight_id
# -fare_conditions
# -amount
#
# tickets
# -ticket_no
# -book_ref
# -passenger_id
#
#
#
#
#
# En español
#
# aircrafts_data
# -aircraft_code(cualitativa)
# -modelo(cualitativa)
# -gama(cualitativa)
#
# airports_data
# -airport_code(cualitativa)
# -airpot_name(cualitativa)
# -ciudad(cualitativa)
# -Coordenadas(cualitativa)
# -zona horaria(cualitativa)
#
# boarding_passes
# -ticket_no(cualitativa)
# -flight_id(cualitativa)
# -boarding_no(cualitativa)
# -seat_no(cualitativa)
#
# Reservas
# -book_ref(cualitativa)
# -book_date(cualitativa)
# -total_amount(cuantitativa)
#
# Vuelos
# -flight_id(cualitativa)
# -flight_no(cualitativa)
# -scheduled_departure(cualitativa)
# -scheduled_arrival(cualitativa)
# -departure_airport(cualitativa)
# -arrival_airport(cualitativa)
# -estado(cualitativa)
# -aircraft_code(cualitativa)
# -actual_departure(cualitativa)
# -actual_arrival(cualitativa)
#
# asientos
# -aircraft_code(cualitativa)
# -seat_no(cualitativa)
# -fare_conditions(cualitativa)
#
# ticket_flights
# -ticket_no(cualitativa)
# -flight_id(cualitativa)
# -fare_conditions(cualitativa)
# -importe(cuantitativa)
#
# Entradas
# -ticket_no(cualitativa)
# -book_ref(cualitativa)
# -passenger_id(cualitativa)
